# %% [markdown]
# # Consumir un modelo LLM local con OpenAI

# %%
# ! python -m pip install openai

# %%
# ! brew install llama.cpp

# %% [markdown]
# ## Inicializar un modelo local en forma de servidor con Llama
#
# ```bash
# llama-server \
#     -m Qwen2.5-3B-Instruct-Q4_K_M.gguf \
#     --host 0.0.0.0 \
#     --port 8080 \
#     -c 4096 \
#     -ngl 99
# ```

# %%
from openai import OpenAI


client = OpenAI(
    base_url="http://localhost:8080/v1",
    api_key="local"
)


response = client.chat.completions.create(
    model="local",
    messages=[
        {
            "role": "system",
            "content": "Eres un asistente especializado en análisis financiero."
        },
        {
            "role": "user",
            "content": """
                Explica en términos sencillos qué significa inflación
                y proporciona un ejemplo relacionado con el precio de alimentos.
            """
        }
    ],
    temperature=0.7
)


print(response.choices[0].message.content)
# Out:
# Claro, te lo explico de manera sencilla.
#
# La inflación es cuando los precios de los productos y servicios suben con el tiempo. Esto significa que con el mismo dinero, puedes comprar menos cosas que antes. Por ejemplo, si hace 10 años un helado te costaba 1 dólar, y hoy cuesta 2 dólares, eso significa que los precios han aumentado y hay inflación.
#
# Ahora, un ejemplo relacionado con el precio de los alimentos:
# Si hace 10 años un kilogramo de tomates te costaba 1 dólar, y hoy cuesta 2 dólares, eso es un ejemplo de inflación. Los tomates, como otros productos de comida, están más caros ahora que antes. Esto significa que para obtener la misma cantidad de alimentos, necesitas más dinero hoy que hace tiempo.
#
# Es importante tener en cuenta que la inflación es normal en una economía, pero si es demasiado alta, puede ser perjudicial para los consumidores y los inversores.
